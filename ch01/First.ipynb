# %%
# !python --version
# Out:
# Python 3.10.12

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
import matplotlib.pyplot as plt

# %%
img =cv2.imread('/content/drive/MyDrive/colabIP/Images/qwe.png')
#cv2_imshow(img)
print(img.shape)
# Out:
# (551, 800, 3)

# %%
plt.imshow(img)
RGB =cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(RGB)
